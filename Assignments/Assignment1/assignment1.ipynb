# %%
import ex1

# %%
df = ex1.experiment_heuristics_astar()
# Out:
# [1/18] Running Problem_pdf with h_improved_astar ...
# <<create_watering_problem
# [2/18] Running problem1 with h_improved_astar ...
# <<create_watering_problem
# [3/18] Running problem2 with h_improved_astar ...
# <<create_watering_problem
# [4/18] Running problem3 with h_improved_astar ...
# <<create_watering_problem
# [5/18] Running problem4 with h_improved_astar ...
# <<create_watering_problem
# [6/18] Running problem5_deadend with h_improved_astar ...
# <<create_watering_problem
# [7/18] Running problem6 with h_improved_astar ...
# <<create_watering_problem
# [8/18] Running problem7 with h_improved_astar ...
# <<create_watering_problem
# [9/18] Running problem_hard1 with h_improved_astar ...
# <<create_watering_problem
# [10/18] Running problem_hard2 with h_improved_astar ...
# <<create_watering_problem
# [11/18] Running problem_hard3 with h_improved_astar ...
# <<create_watering_problem
# [12/18] Running problem_hard4 with h_improved_astar ...
# <<create_watering_problem
# ...

# %%
df.to_csv('results5.csv', index=False)
